# %% [markdown]
# <h4>1. Create a class named Car with attributes make, model, and year. Create an object of the class and print its attributes.</h4>
#
# <h4>2.Add a method named start_engine to the Car class that prints a message when the engine starts. Create an object of the class and call the method.</h4>

# %%
class Car:
    def __init__(self,make,model,year):
        self.make = make
        self.model = model
        self.year = year

    def cardetails(self):
        print(f"Yout car model is {self.model} made by {self.make} in year {self.year}")

    def startEngine(self):
        print("Your Engine is Started ")

tesla = Car("Elon Musk","E",2019)
tesla.cardetails()
tesla.startEngine()
# Out:
# Yout car model is E made by Elon Musk in year 2019
# Your Engine is Started

# %% [markdown]
# <h4>3. Create a class named Student with attributes name and age. Use a constructor to initialize these attributes. Create an object of the class and print its attributes.</h4>

# %%
class Student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
        print(f"Student name is {self.name} and age is {self.age}")
        
student1 = Student("Jaivin",22)
# Out:
# Student name is Jaivin and age is 22

# %% [markdown]
# <h4>4.Create a class named BankAccount with private attributes account_number and balance. Add methods to deposit and withdraw money, and to check the balance. Create an object of the class and perform some operations.</h4>

# %%
## __Var is private variable , we can not access this variable outside the class okay
class BankAccount:
    def __init__(self,accno,bal):
        self.__accno = accno
        self.__bal = bal

    def withdrow(self,amount):
        if self.__bal >= amount:
            self.__bal = self.__bal - amount
            print(f"Successfully Withdrow {amount} and Your Remining Amount is {self.__bal}")
        else:
            print("Sorry Yaar You are not able to withdrow Money ,Because Your Balance is Low , please check Your balance")

    def deposit(self,amount):
        self.__bal = self.__bal + amount
        print(f"Successfully added {amount} and Your Balance is {self.__bal}")

    def chkBalance(self):
        print(f"Your Balance is {self.__bal}")

person1 = BankAccount(10207712,1000000)
person1.chkBalance()
person1.deposit(20000)
person1.withdrow(50000000)
# Out:
# Your Balance is 1000000
# Successfully added 20000 and Your Balance is 1020000
# Sorry Yaar You are not able to withdrow Money ,Because Your Balance is Low , please check Your balance

# %% [markdown]
# <h4>5.Create a base class named Person with attributes name and age. Create a derived class named Employee that inherits from Person and adds an attribute employee_id. Create an object of the derived class and print its attributes.
#
# <h4>6.In the Employee class, override the __str__ method to return a string representation of the object. Create an object of the class and print it.</h4>

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age


class Employee(Person):
    def __init__(self,name,age,emp_id):
        super().__init__(name,age)
        self.emp_id = emp_id

        print(f"{name} , {age} , {self.emp_id}")

    def __str__(self):
         return  f"Employee(Name: {self.name}, Age: {self.age}, Employee ID: {self.emp_id})"
    

#Create object
person1 = Employee("Jaivin",22,102)
print(person1)
# Out:
# Jaivin , 22 , 102
# Employee(Name: Jaivin, Age: 22, Employee ID: 102)

# %% [markdown]
# <h4>7.Create a class named Address with attributes street, city, and zipcode. Create a class named Person that has an Address object as an attribute. Create an object of the Person class and print its address.</h4>

# %%
class Address:
    def __init__(self,street,city,zipcode):
        self.street = street
        self.city = city
        self.zipcode = zipcode
class Person:
    def __init__(self,address):
        self.address = address

address = Address("abc","Ahmedabad",380001)
person1 = Person(address)
print(person1.address.street,person1.address.city,person1.address.zipcode)
# Out:
# abc Ahmedabad 380001
